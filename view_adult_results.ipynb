# %%
import numpy as np

# Choose the file you want to inspect
file_path = 'results/Adult/map_baseline.npy'

# Load the data
# allow_pickle=True is important because the array contains Python dictionaries
data = np.load(file_path, allow_pickle=True)

# Print the contents
print(data)
# Out:
# [{'conf': 0.5297630429267883, 'nll': 0.6605949997901917, 'acc': 0.7654826641082764, 'test_time': 0.31143368530273435}]
